# %% [markdown]
# # Calculate distance between 2 elements

# %%
# %config InlineBackend.figure_format='svg'
# %run MinDist.py GATA3IDR10k.bed D7CTCFCHIP.bed tag=MinDist_GATA3_CTCF_all_hg19
# Out:
# Maximum Number of Items in a Bin:  2312
# [11, 57, 2092, 2273, 743, 790, 2312, 2041, 58, 9]
# done plotting

# %%
# %run MinDist.py GATA3IDR10k.bed CTCF_down.bed tag=MinDist_GATA3_CTCF_down_hg19
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'MinDist.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-d5bc7feec0f1> in <module>
# ...

# %%
# %run MinDist.py CTCF_down.bed TSS.bed tag=MinDist_TSS_CTCF_down_hg19
# Out:
# Maximum Number of Items in a Bin:  490
# [29, 62, 490, 378, 348, 409, 418, 479, 59, 21]
# done plotting

# %%
# %run -i MinDist.py GATA3IDR10k.bed TSS.bed tag=MinDist_TSS_GATA3_hg19
# Out:
# Maximum Number of Items in a Bin:  2716
# [204, 455, 2627, 1451, 392, 433, 1501, 2716, 411, 196]
# done plotting

# %%
# %run MinDist.py GATA3IDR10k.bed TSS.bed tag=MinDist_TSS_GATA3_down_hg19
# Out:
# Maximum Number of Items in a Bin:  2716
# [204, 455, 2627, 1451, 392, 433, 1501, 2716, 411, 196]
# done plotting

# %%
# %run MinDist.py GATA3_10k_looped_bound_CTCFdown_hg19.bed D7CTCFCHIP.bed tag=MinDist_CTCFall_GATA3loopedbound_all_hg19 
# %config InlineBackend.figure_format='svg'
# Out:
# Maximum Number of Items in a Bin:  993
# [0, 1, 241, 609, 993, 897, 643, 221, 0, 0]
# done plotting

# %%
# %run MinDist.py GATA3_10k_looped_bound_CTCFdown_hg19.bed CTCF_down.bed tag=MinDist_CTCFall_GATA3loopedbound_down_hg19 
# %config InlineBackend.figure_format='svg'
# Out:
# Maximum Number of Items in a Bin:  1018
# [17, 180, 949, 286, 336, 299, 385, 1018, 124, 11]
# done plotting

# %%
# %config InlineBackend.figure_format='svg'
# %run MinDist.py CTCF_down_hg38.bed arrowheadTADs.bed tag=MinDist_CTCFdown_TADS_hg38
# Out:
# Maximum Number of Items in a Bin:  597
# [259, 291, 597, 53, 6, 8, 40, 581, 322, 270]
# done plotting

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
# %run MinDist.py DMP_SWAN.bed CTCF_down.bed tag=MinDist_DMP_CTCF_down_hg19
# Out:
# Maximum Number of Items in a Bin:  14495
# [4619, 5774, 14495, 2716, 782, 828, 2812, 14414, 6027, 4686]
# done plotting

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
# %run MinDist.py DMP_hg38.bed  AHDC1_ENCODE_1_2_sorted.bed tag=MinDist_ENCODE_DMP_hg38
# Out:
# Maximum Number of Items in a Bin:  14159
# [829, 1767, 13853, 8717, 3158, 3169, 8858, 14159, 1759, 905]
# done plotting
